# %%
from pathlib import Path
import pandas as pd

# %%
REPO_ROOT_PATH = Path('..')

# %%
MD_OUTPUT_COLS = [
    'seq',
    'GT_Dets',
    'Dets',
    'GT_IDs',
    'IDs',
    'MOTA',
    'CLR_TP',
    'CLR_FN',
    'CLR_FP',
    'IDSW',
    'IDF1',
    'IDR',
    'IDP'
]

# %%
tracker_name = 'similari_iou'
detections_src = 'rapid'
file_path = REPO_ROOT_PATH / 'data' / 'WEPDTOF' / 'eval_output' / '_'.join((detections_src, tracker_name)) / 'person_detailed.csv'
df = pd.read_csv(file_path)
df.style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4b86d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b86d_level0_col0" class="col_heading level0 col0" >seq</th>
#       <th id="T_4b86d_level0_col1" class="col_heading level0 col1" >MOTA</th>
#       <th id="T_4b86d_level0_col2" class="col_heading level0 col2" >MOTP</th>
#       <th id="T_4b86d_level0_col3" class="col_heading level0 col3" >MODA</th>
#       <th id="T_4b86d_level0_col4" class="col_heading level0 col4" >CLR_Re</th>
#       <th id="T_4b86d_level0_col5" class="col_heading level0 col5" >CLR_Pr</th>
#       <th id="T_4b86d_level0_col6" class="col_heading level0 col6" >MTR</th>
#       <th id="T_4b86d_level0_col7" class="col_heading level0 col7" >PTR</th>
#       <th id="T_4b86d_level0_col8" class="col_heading level0 col8" >MLR</th>
#       <th id="T_4b86d_level0_col9" class="col_heading level0 col9" >sMOTA</th>
# ...

# %%
tracker_name = 'similari_iou'
detections_src = 'rapid'
file_path = REPO_ROOT_PATH / 'data' / 'WEPDTOF' / 'eval_output' / '_'.join((detections_src, tracker_name)) / 'person_detailed.csv'
df = pd.read_csv(file_path)
print(df.loc[:, MD_OUTPUT_COLS].to_markdown(index=False, floatfmt=".2f"))
# Out:
# | seq               |   GT_Dets |   Dets |   GT_IDs |   IDs |   MOTA |   CLR_TP |   CLR_FN |   CLR_FP |   IDSW |   IDF1 |   IDR |   IDP |
# |:------------------|----------:|-------:|---------:|------:|-------:|---------:|---------:|---------:|-------:|-------:|------:|------:|
# | call_center       |     17036 |  10335 |       29 |    65 |   0.26 |     7364 |     9672 |     2971 |     11 |   0.48 |  0.39 |  0.64 |
# | convenience_store |      6563 |   7007 |        7 |    16 |   0.83 |     6236 |      327 |      771 |      9 |   0.77 |  0.80 |  0.75 |
# | empty_store       |       358 |    344 |        1 |     1 |  -0.87 |       16 |      342 |      328 |      0 |   0.05 |  0.04 |  0.05 |
# | exhibition        |      9991 |  26869 |       17 |   192 |  -0.87 |     9084 |      907 |    17785 |     32 |   0.35 |  0.65 |  0.24 |
# | exhibition_setup  |     10915 |   6687 |        9 |    65 |  -0.61 |       14 |    10901 |     6673 |      0 |   0.00 |  0.00 |  0.00 |
# ...

# %%
tracker_name = 'similari_iou'
detections_src = 'GT'
file_path = REPO_ROOT_PATH / 'data' / 'WEPDTOF' / 'eval_output' / '_'.join((detections_src, tracker_name)) / 'person_detailed.csv'
df = pd.read_csv(file_path)
df.style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bc374">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc374_level0_col0" class="col_heading level0 col0" >seq</th>
#       <th id="T_bc374_level0_col1" class="col_heading level0 col1" >MOTA</th>
#       <th id="T_bc374_level0_col2" class="col_heading level0 col2" >MOTP</th>
#       <th id="T_bc374_level0_col3" class="col_heading level0 col3" >MODA</th>
#       <th id="T_bc374_level0_col4" class="col_heading level0 col4" >CLR_Re</th>
#       <th id="T_bc374_level0_col5" class="col_heading level0 col5" >CLR_Pr</th>
#       <th id="T_bc374_level0_col6" class="col_heading level0 col6" >MTR</th>
#       <th id="T_bc374_level0_col7" class="col_heading level0 col7" >PTR</th>
#       <th id="T_bc374_level0_col8" class="col_heading level0 col8" >MLR</th>
#       <th id="T_bc374_level0_col9" class="col_heading level0 col9" >sMOTA</th>
# ...

# %%
tracker_name = 'similari_iou'
detections_src = 'GT'
file_path = REPO_ROOT_PATH / 'data' / 'WEPDTOF' / 'eval_output' / '_'.join((detections_src, tracker_name)) / 'person_detailed.csv'
df = pd.read_csv(file_path)
print(df.loc[:, MD_OUTPUT_COLS].to_markdown(index=False, floatfmt=".2f"))
# Out:
# | seq               |   GT_Dets |   Dets |   GT_IDs |   IDs |   MOTA |   CLR_TP |   CLR_FN |   CLR_FP |   IDSW |   IDF1 |   IDR |   IDP |
# |:------------------|----------:|-------:|---------:|------:|-------:|---------:|---------:|---------:|-------:|-------:|------:|------:|
# | call_center       |     17036 |  17957 |       29 |    43 |   0.94 |    16975 |       61 |      982 |     13 |   0.89 |  0.92 |  0.87 |
# | convenience_store |      6563 |   6621 |        7 |     9 |   0.98 |     6543 |       20 |       78 |      2 |   0.99 |  0.99 |  0.99 |
# | empty_store       |       358 |    356 |        1 |     1 |   0.97 |      352 |        6 |        4 |      0 |   0.99 |  0.98 |  0.99 |
# | exhibition        |      9991 |  10677 |       17 |    26 |   0.92 |     9934 |       57 |      743 |      9 |   0.91 |  0.94 |  0.88 |
# | exhibition_setup  |     10915 |  13481 |        9 |    40 |  -1.19 |      240 |    10675 |    13241 |      4 |   0.01 |  0.01 |  0.01 |
# ...
